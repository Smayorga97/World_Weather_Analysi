# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import API key
from config import g_key
# gmaps 
import gmaps
# Import the API key.
from config import weather_api_key
# Import the time module.
import time

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key = g_key)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0ac43cb744c4df9d355e8ac86af4b5e9

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 626

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
      
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | poum
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | quatre cocos
# Processing Record 5 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | palauig
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | los llanos de aridane
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | guayaramerin
# Processing Record 16 of Set 1 | roma
# Processing Record 17 of Set 1 | cockburn town
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | lazaro cardenas
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | olafsvik
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | camacha
# Processing Record 26 of Set 1 | broken hill
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | piney green
# Processing Record 29 of Set 1 | novoorsk
# Processing Record 30 of Set 1 | korla
# Processing Record 31 of Set 1 | kautokeino
# Processing Record 32 of Set 1 | maria la baja
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | amazar
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | gladstone
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | narsaq
# Processing Record 39 of Set 1 | buala
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 1 | ozernovskiy
# Processing Record 45 of Set 1 | mount gambier
# Processing Record 46 of Set 1 | khor
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | new castle
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | puerto baquerizo moreno
# Processing Record 1 of Set 2 | twin falls
# Processing Record 2 of Set 2 | maniitsoq
# Processing Record 3 of Set 2 | kruisfontein
# Processing Record 4 of Set 2 | rosetta
# Processing Record 5 of Set 2 | mayumba
# Processing Record 6 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | bengkulu
# Processing Record 11 of Set 2 | tibati
# Processing Record 12 of Set 2 | tuatapere
# Processing Record 13 of Set 2 | ust-nera
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 2 | tual
# Processing Record 17 of Set 2 | manta
# Processing Record 18 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 2 | etchoropo
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | kiunga
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | necochea
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | san policarpo
# Processing Record 27 of Set 2 | ola
# Processing Record 28 of Set 2 | east islip
# Processing Record 29 of Set 2 | ornskoldsvik
# Processing Record 30 of Set 2 | nisia floresta
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | birao
# Processing Record 33 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 2 | okhotsk
# Processing Record 35 of Set 2 | port hardy
# Processing Record 36 of Set 2 | thunder bay
# Processing Record 37 of Set 2 | lebane
# Processing Record 38 of Set 2 | cabinda
# Processing Record 39 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | ulaanbaatar
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 2 | la ronge
# Processing Record 47 of Set 2 | wairoa
# Processing Record 48 of Set 2 | copiapo
# Processing Record 49 of Set 2 | husavik
# Processing Record 50 of Set 2 | srednekolymsk
# Processing Record 1 of Set 3 | esperance
# Processing Record 2 of Set 3 | hodal
# Processing Record 3 of Set 3 | san patricio
# Processing Record 4 of Set 3 | jieshi
# Processing Record 5 of Set 3 | severo-kurilsk
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | khatanga
# Processing Record 8 of Set 3 | tiznit
# Processing Record 9 of Set 3 | bone
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | kaka
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | sobolevo
# Processing Record 15 of Set 3 | severnyy
# Processing Record 16 of Set 3 | yulara
# Processing Record 17 of Set 3 | pevek
# Processing Record 18 of Set 3 | novichikha
# Processing Record 19 of Set 3 | bilibino
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | patiya
# Processing Record 22 of Set 3 | andros town
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | mahebourg
# Processing Record 25 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 3 | monrovia
# Processing Record 27 of Set 3 | norman wells
# Processing Record 28 of Set 3 | bernau
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | cukai
# Processing Record 35 of Set 3 | ban tak
# Processing Record 36 of Set 3 | nienburg
# Processing Record 37 of Set 3 | mitsamiouli
# Processing Record 38 of Set 3 | yar-sale
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | maragogi
# Processing Record 41 of Set 3 | mao
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | palmer
# Processing Record 44 of Set 3 | padang
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | karratha
# Processing Record 47 of Set 3 | kavaratti
# Processing Record 48 of Set 3 | teguldet
# Processing Record 49 of Set 3 | lloydminster
# Processing Record 50 of Set 3 | grindavik
# Processing Record 1 of Set 4 | margate
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | ayagoz
# Processing Record 4 of Set 4 | pringsewu
# Processing Record 5 of Set 4 | lensk
# Processing Record 6 of Set 4 | goderich
# Processing Record 7 of Set 4 | luderitz
# Processing Record 8 of Set 4 | vaini
# Processing Record 9 of Set 4 | aklavik
# Processing Record 10 of Set 4 | kavieng
# Processing Record 11 of Set 4 | pangody
# Processing Record 12 of Set 4 | itabirito
# Processing Record 13 of Set 4 | oktyabrskoye
# Processing Record 14 of Set 4 | san rafael del sur
# Processing Record 15 of Set 4 | kaitangata
# Processing Record 16 of Set 4 | shingu
# Processing Record 17 of Set 4 | manado
# Processing Record 18 of Set 4 | port elizabeth
# Processing Record 19 of Set 4 | tumpat
# Processing Record 20 of Set 4 | mayor pablo lagerenza
# Processing Record 21 of Set 4 | coolum beach
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | mapiripan
# Processing Record 24 of Set 4 | rio grande
# Processing Record 25 of Set 4 | noumea
# Processing Record 26 of Set 4 | forestville
# Processing Record 27 of Set 4 | touros
# Processing Record 28 of Set 4 | duluth
# Processing Record 29 of Set 4 | nizhnyaya tura
# Processing Record 30 of Set 4 | alice town
# Processing Record 31 of Set 4 | mount isa
# Processing Record 32 of Set 4 | hervey bay
# Processing Record 33 of Set 4 | suhbaatar
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | kamenka
# Processing Record 36 of Set 4 | kuito
# Processing Record 37 of Set 4 | lucapa
# Processing Record 38 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 4 | vilyuysk
# Processing Record 40 of Set 4 | kisangani
# Processing Record 41 of Set 4 | creemore
# Processing Record 42 of Set 4 | port hedland
# Processing Record 43 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 4 | shimoda
# Processing Record 45 of Set 4 | susanville
# Processing Record 46 of Set 4 | klyuchi
# Processing Record 47 of Set 4 | rongcheng
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | tete
# Processing Record 50 of Set 4 | bolshiye uki
# City not found. Skipping...
# Processing Record 1 of Set 5 | vychegodskiy
# Processing Record 2 of Set 5 | chokurdakh
# Processing Record 3 of Set 5 | tasiilaq
# Processing Record 4 of Set 5 | upernavik
# Processing Record 5 of Set 5 | tessalit
# Processing Record 6 of Set 5 | san vicente
# Processing Record 7 of Set 5 | saskylakh
# Processing Record 8 of Set 5 | leningradskiy
# Processing Record 9 of Set 5 | morant bay
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | ponta do sol
# Processing Record 12 of Set 5 | zonguldak
# Processing Record 13 of Set 5 | guerrero negro
# Processing Record 14 of Set 5 | yellowknife
# Processing Record 15 of Set 5 | vardo
# Processing Record 16 of Set 5 | challapata
# Processing Record 17 of Set 5 | tecoanapa
# Processing Record 18 of Set 5 | portland
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | manyana
# Processing Record 21 of Set 5 | hualmay
# Processing Record 22 of Set 5 | airai
# Processing Record 23 of Set 5 | okahandja
# Processing Record 24 of Set 5 | kalmunai
# Processing Record 25 of Set 5 | ouallam
# Processing Record 26 of Set 5 | faya
# Processing Record 27 of Set 5 | alacranes
# Processing Record 28 of Set 5 | kismayo
# Processing Record 29 of Set 5 | vila velha
# Processing Record 30 of Set 5 | turayf
# Processing Record 31 of Set 5 | heswall
# Processing Record 32 of Set 5 | suntar
# Processing Record 33 of Set 5 | dhidhdhoo
# Processing Record 34 of Set 5 | harper
# Processing Record 35 of Set 5 | juegang
# Processing Record 36 of Set 5 | altay
# Processing Record 37 of Set 5 | barcelos
# Processing Record 38 of Set 5 | acheng
# Processing Record 39 of Set 5 | babu
# Processing Record 40 of Set 5 | dwarka
# Processing Record 41 of Set 5 | barrow
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | lata
# Processing Record 44 of Set 5 | kodinsk
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | los alamos
# Processing Record 48 of Set 5 | san quintin
# Processing Record 49 of Set 5 | along
# Processing Record 50 of Set 5 | nobeoka
# Processing Record 1 of Set 6 | nara
# Processing Record 2 of Set 6 | sao jose da coroa grande
# Processing Record 3 of Set 6 | watsa
# Processing Record 4 of Set 6 | new norfolk
# Processing Record 5 of Set 6 | ribeira grande
# Processing Record 6 of Set 6 | sorong
# Processing Record 7 of Set 6 | chuy
# Processing Record 8 of Set 6 | mosquera
# Processing Record 9 of Set 6 | parana
# Processing Record 10 of Set 6 | burns lake
# Processing Record 11 of Set 6 | nome
# Processing Record 12 of Set 6 | thoen
# Processing Record 13 of Set 6 | lozuvatka
# Processing Record 14 of Set 6 | rafsanjan
# Processing Record 15 of Set 6 | talara
# Processing Record 16 of Set 6 | akdepe
# Processing Record 17 of Set 6 | tsaratanana
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | tiksi
# Processing Record 20 of Set 6 | port blair
# Processing Record 21 of Set 6 | rezh
# Processing Record 22 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | luganville
# Processing Record 24 of Set 6 | chantada
# Processing Record 25 of Set 6 | olavarria
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | havre-saint-pierre
# Processing Record 28 of Set 6 | anadyr
# Processing Record 29 of Set 6 | matara
# Processing Record 30 of Set 6 | yumen
# Processing Record 31 of Set 6 | torbay
# Processing Record 32 of Set 6 | zherdevka
# Processing Record 33 of Set 6 | cabedelo
# Processing Record 34 of Set 6 | lewistown
# Processing Record 35 of Set 6 | mandan
# Processing Record 36 of Set 6 | sur
# Processing Record 37 of Set 6 | sembabule
# Processing Record 38 of Set 6 | kushiro
# Processing Record 39 of Set 6 | jumla
# Processing Record 40 of Set 6 | richards bay
# Processing Record 41 of Set 6 | arman
# Processing Record 42 of Set 6 | lianran
# Processing Record 43 of Set 6 | nanortalik
# Processing Record 44 of Set 6 | lumut
# Processing Record 45 of Set 6 | haines junction
# Processing Record 46 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 48 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | fontaine
# Processing Record 50 of Set 6 | isetskoye
# Processing Record 1 of Set 7 | gergebil
# Processing Record 2 of Set 7 | mirebalais
# Processing Record 3 of Set 7 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 7 | praia da vitoria
# Processing Record 5 of Set 7 | bakchar
# Processing Record 6 of Set 7 | derzhavinsk
# Processing Record 7 of Set 7 | awbari
# Processing Record 8 of Set 7 | manacor
# Processing Record 9 of Set 7 | junin
# Processing Record 10 of Set 7 | alice springs
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | iralaya
# Processing Record 13 of Set 7 | kamaishi
# Processing Record 14 of Set 7 | strezhevoy
# Processing Record 15 of Set 7 | gilgit
# Processing Record 16 of Set 7 | coihaique
# Processing Record 17 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 7 | teeli
# Processing Record 19 of Set 7 | laguna
# Processing Record 20 of Set 7 | yenangyaung
# Processing Record 21 of Set 7 | longyearbyen
# Processing Record 22 of Set 7 | lebu
# Processing Record 23 of Set 7 | sisimiut
# Processing Record 24 of Set 7 | payo
# Processing Record 25 of Set 7 | balabac
# Processing Record 26 of Set 7 | namwala
# Processing Record 27 of Set 7 | longkou
# Processing Record 28 of Set 7 | houlton
# Processing Record 29 of Set 7 | ciechocinek
# Processing Record 30 of Set 7 | tura
# Processing Record 31 of Set 7 | aswan
# Processing Record 32 of Set 7 | lagoa
# Processing Record 33 of Set 7 | esil
# Processing Record 34 of Set 7 | faanui
# Processing Record 35 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 7 | samarai
# Processing Record 37 of Set 7 | at-bashi
# Processing Record 38 of Set 7 | port keats
# Processing Record 39 of Set 7 | san ignacio
# Processing Record 40 of Set 7 | caceres
# Processing Record 41 of Set 7 | caravelas
# Processing Record 42 of Set 7 | zheleznodorozhnyy
# Processing Record 43 of Set 7 | ndende
# Processing Record 44 of Set 7 | lompoc
# Processing Record 45 of Set 7 | cururupu
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | krasnoborsk
# Processing Record 48 of Set 7 | nembro
# Processing Record 49 of Set 7 | tilichiki
# Processing Record 50 of Set 7 | manzhouli
# Processing Record 1 of Set 8 | daru
# Processing Record 2 of Set 8 | sorland
# Processing Record 3 of Set 8 | synya
# Processing Record 4 of Set 8 | fairbanks
# Processing Record 5 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 8 | corrales
# Processing Record 7 of Set 8 | cotonou
# Processing Record 8 of Set 8 | half moon bay
# Processing Record 9 of Set 8 | ardabil
# Processing Record 10 of Set 8 | byron bay
# Processing Record 11 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 12 of Set 8 | namatanai
# Processing Record 13 of Set 8 | taksimo
# Processing Record 14 of Set 8 | kalianget
# Processing Record 15 of Set 8 | seoul
# Processing Record 16 of Set 8 | erenhot
# Processing Record 17 of Set 8 | oildale
# Processing Record 18 of Set 8 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 19 of Set 8 | thaton
# Processing Record 20 of Set 8 | eyl
# Processing Record 21 of Set 8 | kidal
# Processing Record 22 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 24 of Set 8 | tanout
# Processing Record 25 of Set 8 | biak
# Processing Record 26 of Set 8 | esso
# Processing Record 27 of Set 8 | lima
# Processing Record 28 of Set 8 | gouyave
# Processing Record 29 of Set 8 | fort-shevchenko
# Processing Record 30 of Set 8 | peterhead
# Processing Record 31 of Set 8 | isangel
# Processing Record 32 of Set 8 | unye
# City not found. Skipping...
# Processing Record 33 of Set 8 | belyy yar
# Processing Record 34 of Set 8 | taoudenni
# Processing Record 35 of Set 8 | ndele
# Processing Record 36 of Set 8 | marsabit
# Processing Record 37 of Set 8 | redding
# Processing Record 38 of Set 8 | inirida
# Processing Record 39 of Set 8 | sinop
# Processing Record 40 of Set 8 | saint-philippe
# Processing Record 41 of Set 8 | kiruna
# Processing Record 42 of Set 8 | mangrul pir
# Processing Record 43 of Set 8 | grand gaube
# Processing Record 44 of Set 8 | makakilo city
# Processing Record 45 of Set 8 | capitao poco
# Processing Record 46 of Set 8 | hanna
# Processing Record 47 of Set 8 | baker city
# Processing Record 48 of Set 8 | antofagasta
# Processing Record 49 of Set 8 | ust-tsilma
# Processing Record 50 of Set 8 | alofi
# Processing Record 1 of Set 9 | shetpe
# Processing Record 2 of Set 9 | hasaki
# Processing Record 3 of Set 9 | yiyang
# Processing Record 4 of Set 9 | kokopo
# Processing Record 5 of Set 9 | jiuquan
# Processing Record 6 of Set 9 | skibbereen
# Processing Record 7 of Set 9 | mehamn
# Processing Record 8 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 9 | chapais
# Processing Record 10 of Set 9 | salou
# Processing Record 11 of Set 9 | poddorye
# Processing Record 12 of Set 9 | rognan
# Processing Record 13 of Set 9 | saldanha
# Processing Record 14 of Set 9 | leshukonskoye
# Processing Record 15 of Set 9 | langsa
# Processing Record 16 of Set 9 | de pere
# Processing Record 17 of Set 9 | pozo colorado
# Processing Record 18 of Set 9 | hobyo
# Processing Record 19 of Set 9 | abai
# Processing Record 20 of Set 9 | taiping
# Processing Record 21 of Set 9 | innisfail
# Processing Record 22 of Set 9 | catuday
# Processing Record 23 of Set 9 | burica
# City not found. Skipping...
# Processing Record 24 of Set 9 | hofn
# Processing Record 25 of Set 9 | batagay-alyta
# Processing Record 26 of Set 9 | saint-augustin
# Processing Record 27 of Set 9 | codrington
# Processing Record 28 of Set 9 | flin flon
# Processing Record 29 of Set 9 | sinnamary
# Processing Record 30 of Set 9 | jiazi
# Processing Record 31 of Set 9 | adrar
# Processing Record 32 of Set 9 | srandakan
# Processing Record 33 of Set 9 | dhadar
# Processing Record 34 of Set 9 | hopkinsville
# Processing Record 35 of Set 9 | sept-iles
# Processing Record 36 of Set 9 | bezhta
# Processing Record 37 of Set 9 | khasan
# Processing Record 38 of Set 9 | santa cruz
# Processing Record 39 of Set 9 | mochudi
# Processing Record 40 of Set 9 | shupiyan
# Processing Record 41 of Set 9 | avera
# Processing Record 42 of Set 9 | pizarro
# Processing Record 43 of Set 9 | sitka
# Processing Record 44 of Set 9 | dicabisagan
# Processing Record 45 of Set 9 | vengerovo
# Processing Record 46 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 9 | mazagao
# Processing Record 48 of Set 9 | verkhnevilyuysk
# Processing Record 49 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 9 | ixtapa
# Processing Record 1 of Set 10 | vanavara
# Processing Record 2 of Set 10 | kaeo
# Processing Record 3 of Set 10 | nueva loja
# Processing Record 4 of Set 10 | kunming
# Processing Record 5 of Set 10 | saurimo
# Processing Record 6 of Set 10 | vung tau
# Processing Record 7 of Set 10 | solnechnyy
# Processing Record 8 of Set 10 | carauari
# Processing Record 9 of Set 10 | paungde
# Processing Record 10 of Set 10 | wawa
# Processing Record 11 of Set 10 | dondo
# Processing Record 12 of Set 10 | dawlatabad
# Processing Record 13 of Set 10 | riyadh
# Processing Record 14 of Set 10 | sao joao da barra
# Processing Record 15 of Set 10 | mpongwe
# Processing Record 16 of Set 10 | aripuana
# Processing Record 17 of Set 10 | salto del guaira
# Processing Record 18 of Set 10 | ouesso
# Processing Record 19 of Set 10 | kemijarvi
# Processing Record 20 of Set 10 | kaspiyskiy
# Processing Record 21 of Set 10 | coahuayana
# Processing Record 22 of Set 10 | rawson
# Processing Record 23 of Set 10 | tateyama
# Processing Record 24 of Set 10 | fare
# Processing Record 25 of Set 10 | lively
# Processing Record 26 of Set 10 | kishi
# Processing Record 27 of Set 10 | ewa beach
# Processing Record 28 of Set 10 | makungu
# Processing Record 29 of Set 10 | iseyin
# Processing Record 30 of Set 10 | ancud
# Processing Record 31 of Set 10 | bolshaya sosnova
# Processing Record 32 of Set 10 | poronaysk
# Processing Record 33 of Set 10 | forio
# Processing Record 34 of Set 10 | hurricane
# Processing Record 35 of Set 10 | chernyshevskiy
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | mahajanga
# Processing Record 38 of Set 10 | terra santa
# Processing Record 39 of Set 10 | vila
# Processing Record 40 of Set 10 | flinders
# Processing Record 41 of Set 10 | calama
# Processing Record 42 of Set 10 | chesma
# Processing Record 43 of Set 10 | turukhansk
# Processing Record 44 of Set 10 | kerrville
# Processing Record 45 of Set 10 | vao
# Processing Record 46 of Set 10 | langarud
# Processing Record 47 of Set 10 | kloulklubed
# Processing Record 48 of Set 10 | santa vitoria
# Processing Record 49 of Set 10 | phimai
# Processing Record 50 of Set 10 | kyshtovka
# Processing Record 1 of Set 11 | kupang
# Processing Record 2 of Set 11 | yefimovskiy
# City not found. Skipping...
# Processing Record 3 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 11 | maceio
# Processing Record 5 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 6 of Set 11 | chabahar
# Processing Record 7 of Set 11 | iracoubo
# Processing Record 8 of Set 11 | namibe
# Processing Record 9 of Set 11 | nouakchott
# Processing Record 10 of Set 11 | tromso
# Processing Record 11 of Set 11 | phalaborwa
# Processing Record 12 of Set 11 | sydney
# Processing Record 13 of Set 11 | nemuro
# Processing Record 14 of Set 11 | trindade
# Processing Record 15 of Set 11 | mizpe ramon
# City not found. Skipping...
# Processing Record 16 of Set 11 | belgaum
# Processing Record 17 of Set 11 | makrikhorion
# City not found. Skipping...
# Processing Record 18 of Set 11 | beyneu
# Processing Record 19 of Set 11 | college
# Processing Record 20 of Set 11 | pinhao
# Processing Record 21 of Set 11 | broumov
# Processing Record 22 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 11 | san pedro
# Processing Record 25 of Set 11 | aykhal
# Processing Record 26 of Set 11 | berlevag
# Processing Record 27 of Set 11 | ulladulla
# Processing Record 28 of Set 11 | kantunilkin
# Processing Record 29 of Set 11 | benjamin aceval
# Processing Record 30 of Set 11 | aakirkeby
# City not found. Skipping...
# Processing Record 31 of Set 11 | urumqi
# Processing Record 32 of Set 11 | tacoronte
# Processing Record 33 of Set 11 | berdigestyakh
# Processing Record 34 of Set 11 | goldsboro
# Processing Record 35 of Set 11 | dunwoody
# Processing Record 36 of Set 11 | labuhan
# Processing Record 37 of Set 11 | guekedou
# City not found. Skipping...
# Processing Record 38 of Set 11 | meadow lake
# Processing Record 39 of Set 11 | lake oswego
# Processing Record 40 of Set 11 | agua verde
# Processing Record 41 of Set 11 | ojinaga
# Processing Record 42 of Set 11 | bathsheba
# Processing Record 43 of Set 11 | dali
# Processing Record 44 of Set 11 | qaqortoq
# Processing Record 45 of Set 11 | mersing
# Processing Record 46 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 47 of Set 11 | lakes entrance
# Processing Record 48 of Set 11 | messina
# Processing Record 49 of Set 11 | bulgan
# Processing Record 50 of Set 11 | kuah
# Processing Record 1 of Set 12 | oberndorf
# Processing Record 2 of Set 12 | muzhi
# Processing Record 3 of Set 12 | gorgan
# Processing Record 4 of Set 12 | shelburne
# Processing Record 5 of Set 12 | marawi
# Processing Record 6 of Set 12 | kiama
# Processing Record 7 of Set 12 | vila franca do campo
# Processing Record 8 of Set 12 | te anau
# Processing Record 9 of Set 12 | vilhena
# Processing Record 10 of Set 12 | sao filipe
# Processing Record 11 of Set 12 | brasileia
# Processing Record 12 of Set 12 | zhangye
# Processing Record 13 of Set 12 | kahului
# Processing Record 14 of Set 12 | cedar city
# Processing Record 15 of Set 12 | ludvika
# Processing Record 16 of Set 12 | san cristobal
# Processing Record 17 of Set 12 | porto velho
# Processing Record 18 of Set 12 | balsas
# Processing Record 19 of Set 12 | zhanaozen
# Processing Record 20 of Set 12 | epinal
# Processing Record 21 of Set 12 | umm lajj
# Processing Record 22 of Set 12 | bayir
# Processing Record 23 of Set 12 | teknaf
# Processing Record 24 of Set 12 | kraskino
# Processing Record 25 of Set 12 | cartagena
# Processing Record 26 of Set 12 | sorochinsk
# Processing Record 27 of Set 12 | asyut
# Processing Record 28 of Set 12 | requena
# Processing Record 29 of Set 12 | ostrovnoy
# Processing Record 30 of Set 12 | pangnirtung
# Processing Record 31 of Set 12 | nabire
# Processing Record 32 of Set 12 | trogir
# Processing Record 33 of Set 12 | kolvereid
# Processing Record 34 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 12 | placido de castro
# Processing Record 36 of Set 12 | dunedin
# Processing Record 37 of Set 12 | hambantota
# Processing Record 38 of Set 12 | hamilton
# Processing Record 39 of Set 12 | asau
# Processing Record 40 of Set 12 | bulolo
# Processing Record 41 of Set 12 | eston
# Processing Record 42 of Set 12 | campbell river
# Processing Record 43 of Set 12 | bambous virieux
# Processing Record 44 of Set 12 | baijiantan
# Processing Record 45 of Set 12 | kendari
# Processing Record 46 of Set 12 | antsohihy
# Processing Record 47 of Set 12 | valparaiso
# Processing Record 48 of Set 12 | san juan de la maguana
# Processing Record 49 of Set 12 | pyaozerskiy
# Processing Record 50 of Set 12 | ahipara
# Processing Record 1 of Set 13 | coffs harbour
# Processing Record 2 of Set 13 | sungairaya
# Processing Record 3 of Set 13 | puerto escondido
# Processing Record 4 of Set 13 | linxia
# Processing Record 5 of Set 13 | kokkola
# Processing Record 6 of Set 13 | fort nelson
# Processing Record 7 of Set 13 | wingham
# Processing Record 8 of Set 13 | kargasok
# Processing Record 9 of Set 13 | chicama
# Processing Record 10 of Set 13 | comodoro rivadavia
# Processing Record 11 of Set 13 | yerofey pavlovich
# Processing Record 12 of Set 13 | tonj
# Processing Record 13 of Set 13 | port augusta
# Processing Record 14 of Set 13 | gharo
# Processing Record 15 of Set 13 | zhenlai
# Processing Record 16 of Set 13 | bundaberg
# Processing Record 17 of Set 13 | luau
# Processing Record 18 of Set 13 | vetralla
# Processing Record 19 of Set 13 | mecca
# Processing Record 20 of Set 13 | yichang
# Processing Record 21 of Set 13 | muscat
# Processing Record 22 of Set 13 | hermiston
# Processing Record 23 of Set 13 | shemgang
# Processing Record 24 of Set 13 | pacific grove
# Processing Record 25 of Set 13 | meulaboh
# Processing Record 26 of Set 13 | iwade
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari   3.0707  172.7902     82.54        71          24
# 1          Poum -20.2333  164.0167     78.89        77           5
# 2       Mataura -46.1927  168.8643     47.48        95         100
# 3  Quatre Cocos -20.2078   57.7625     75.09        63          26
# 4    Georgetown   5.4112  100.3354     87.73        70          20
#
#    Wind Speed Country Current Description
# 0       12.82      KI          few clouds
# 1       12.97      NC           clear sky
# 2        7.49      NZ          light rain
# 3       15.37      MU    scattered clouds
# 4        6.91      MY          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Butaritari      KI   3.0707  172.7902     82.54        71          24
# 1          Poum      NC -20.2333  164.0167     78.89        77           5
# 2       Mataura      NZ -46.1927  168.8643     47.48        95         100
# 3  Quatre Cocos      MU -20.2078   57.7625     75.09        63          26
# 4    Georgetown      MY   5.4112  100.3354     87.73        70          20
#
#    Wind Speed Current Description
# 0       12.82          few clouds
# 1       12.97           clear sky
# 2        7.49          light rain
# 3       15.37    scattered clouds
# 4        6.91          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_challenge.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
